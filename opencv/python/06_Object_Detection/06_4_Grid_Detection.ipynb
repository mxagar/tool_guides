# %% [markdown]
# # 6 Object Detection
# - Template matching
# - Corner detection
# - Edge Detection
# - Grid detection
# - Contour detection
# - Feature matching: most advanced method
# - Watershed
# - Facial and eye detection with Haar cascades
# - Project: blurring license plates

# %% [markdown]
# ## 6.4 Grid Detection

# %% [markdown]
# Grid-like patterns are common for camera calibration and tracking.
# Thus, these functions are the basis for camera calibration.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Chessboard

# %%
flat_chess = cv2.imread('../../data/flat_chessboard.png')

# %%
flat_chess.shape
# Out:
# (352, 352, 3)

# %%
plt.imshow(flat_chess)

# %%
# image + grid size is passed
# but: since our chess board has mo margins, borders are not counted: 9 -> 7
# returned: true if found, corner coordinates
found,corners = cv2.findChessboardCorners(flat_chess,(7,7))

# %%
found
# Out:
# True

# %%
# input similar to cv2.findChessboardCorners()
# output: image with rainbow-color coded corners
flat_chess_corners = cv2.drawChessboardCorners(flat_chess, (7,7), corners, found)

# %%
plt.imshow(flat_chess_corners)

# %% [markdown]
# ### Dot Grid

# %%
dots = cv2.imread('../../data/dot_grid.png')

# %%
plt.imshow(dots)

# %%
# input: now, we have enough margin to consider all dots
# output: same as with cv2.findChessboardCorners(): true if found, coorner/dot coordinates
found, corners = cv2.findCirclesGrid(dots, (10,10), cv2.CALIB_CB_SYMMETRIC_GRID)

# %%
# same function as before used for drawing color-coded pattern
dots_corners = cv2.drawChessboardCorners(dots, (10,10), corners, found)

# %%
plt.imshow(dots_corners)
